# %%
import numpy as np
import matplotlib.pyplot as matplot

# %%
maasList = numpy.random.normal(4000, 500, 1000)

# %%
numpy.mean(maasList)
# Out:
# 4016.7695223134233

# %%
matplot.hist(maasList, 50)
matplot.show()

# %%
#modüller tek başına python dosyalarıdır. paketler ise daha geniş kapsamlısıdır.
